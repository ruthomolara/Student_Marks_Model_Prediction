# %%
import pandas as pd
import numpy as py
from statistics import mode
import matplotlib. pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("Student_Marks.csv")
print(df)
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
print(df.head(5))
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB
# None

# %%
print (df.describe())
# Out:
#        number_courses  time_study       Marks
# count      100.000000  100.000000  100.000000
# mean         5.290000    4.077140   24.417690
# std          1.799523    2.372914   14.326199
# min          3.000000    0.096000    5.609000
# 25%          4.000000    2.058500   12.633000
# 50%          5.000000    4.022000   20.059500
# 75%          7.000000    6.179250   36.676250
# max          8.000000    7.957000   55.299000

# %%
df
# Out:
#     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]

# %%
#Display data into features and targets.

# %%
x = df.drop("Marks", axis = 1)
print(x)
# Out:
#     number_courses  time_study
# 0                3       4.508
# 1                4       0.096
# 2                4       3.133
# 3                6       7.909
# 4                8       7.811
# ..             ...         ...
# 95               6       3.561
# 96               3       0.301
# 97               4       7.163
# 98               7       0.309
# 99               3       6.335
#
# [100 rows x 2 columns]

# %%
y = df ["Marks"]
print (y)
# Out:
# 0     19.202
# 1      7.734
# 2     13.811
# 3     53.018
# 4     55.299
#        ...
# 95    19.128
# 96     5.609
# 97    41.444
# 98    12.027
# 99    32.357
# Name: Marks, Length: 100, dtype: float64

# %%
#Display split data into a training set and test set (80% of data for training and 20% for testing)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size =0.2,random_state =42)

# %%
#Building a linear Regression Model

# %%
lr_model = LinearRegression()

# %%
lr_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr_predictions = lr_model.predict(x_test)
print(lr_predictions)
# Out:
# [19.27278272 37.76035676 20.18779372  9.65670863 10.97508223 44.81200554
#  13.34810968 47.62447209 37.01567001 22.30738483 44.48113375 28.33573684
#   7.42332402 38.70638699 28.10820618 48.74122069 35.72331468 39.30103485
#  28.29432156  8.94326632]

# %%
#x_train, x_test (Features=independent variable)

# %%
#y_train, y_test (Target=dependent variable)

# %%
#Building a Random Forest Model

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
print(rf_model)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_model.fit (x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
rf_predictions = rf_model.predict(x_test)
print(rf_predictions)
# Out:
# [16.44918 35.56641 16.92413 10.42055 11.0462  50.95797 12.55124 52.14082
#  43.89374 20.07702 50.99347 22.3653   7.59664 40.89446 23.16644 52.75318
#  38.48433 36.21883 22.96653 10.07079]

# %%
lr_predictions = lr_model.predict(x_test)

# %%
lr_mse = mean_squared_error(y_test, lr_prediction)
print("Linear Regression Mean Squared error:", lr_mse)
# Out:
# Linear Regression Mean Squared error: 14.200726136374538

# %%
rf_predictions = rf_model.predict(x_test)
print(rf_predictions)
# Out:
# [16.44918 35.56641 16.92413 10.42055 11.0462  50.95797 12.55124 52.14082
#  43.89374 20.07702 50.99347 22.3653   7.59664 40.89446 23.16644 52.75318
#  38.48433 36.21883 22.96653 10.07079]

# %%
rf_mse = mean_squared_error(y_test, rf_predictions)
print(rf_mse)
# Out:
# 1.9944720109850334

# %%
# The lower the error, the better the model 
lr_mse =  14.200726136374538
rf_mse =  1.9944720109850334
